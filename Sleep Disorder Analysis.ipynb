# %% [markdown]
# # Sleep Disorder Analysis
# Sleep disorders are increasingly recognized as a major public health concern, affecting physical health, mental well-being, and daily productivity. The Sleep_disorder_data dataset provides a rich, multidimensional view of individual health and lifestyle factors—including sleep duration, quality of sleep, physical activity, stress levels, BMI category, and vital signs—alongside attributes like age, gender, and occupation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"D:\MODULE 3 -- PYTHON\Sleep Disorder Analysis\Beginner - Sleep Disorder Analysis-20250819T063942Z-1-001\Beginner - Sleep Disorder Analysis\Sleep_disorder_data.csv",index_col=0,header=0)

# %%
pd.set_option('display.max_rows',None)
df.head()
# Out:
#           Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 1           Male   27     Software Engineer             6.1                 6
# 2           Male   28                Doctor             6.2                 6
# 3           Male   28                Doctor             6.2                 6
# 4           Male   28  Sales Representative             5.9                 4
# 5           Male   28  Sales Representative             5.9                 4
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 1                               42             6   Overweight         126/83
# 2                               60             8       Normal         125/80
# 3                               60             8       Normal         125/80
# 4                               30             8        Obese         140/90
# 5                               30             8        Obese         140/90
#
# ...

# %%
df.dtypes
# Out:
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df.shape
# Out:
# (374, 12)

# %%
d=df.dropna() 
d.shape
# Out:
# (155, 12)

# %%
d=df.fillna(value='NA')

# %%
df.duplicated().sum()
# Out:
# np.int64(242)

# %%
d=df.drop_duplicates()
d.shape
# Out:
# (132, 12)

# %%
df.head()
# Out:
#           Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 1           Male   27     Software Engineer             6.1                 6
# 2           Male   28                Doctor             6.2                 6
# 3           Male   28                Doctor             6.2                 6
# 4           Male   28  Sales Representative             5.9                 4
# 5           Male   28  Sales Representative             5.9                 4
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 1                               42             6   Overweight         126/83
# 2                               60             8       Normal         125/80
# 3                               60             8       Normal         125/80
# 4                               30             8        Obese         140/90
# 5                               30             8        Obese         140/90
#
# ...

# %%
df.tail()
# Out:
#            Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 370        Female   59      Nurse             8.1                 9
# 371        Female   59      Nurse             8.0                 9
# 372        Female   59      Nurse             8.1                 9
# 373        Female   59      Nurse             8.1                 9
# 374        Female   59      Nurse             8.1                 9
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 370                             75             3   Overweight         140/95
# 371                             75             3   Overweight         140/95
# 372                             75             3   Overweight         140/95
# 373                             75             3   Overweight         140/95
# 374                             75             3   Overweight         140/95
#
#            Heart Rate  Daily Steps Sleep Disorder
# Person ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 374 entries, 1 to 374
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    object
#  1   Age                      374 non-null    int64
#  2   Occupation               374 non-null    object
#  3   Sleep Duration           374 non-null    float64
#  4   Quality of Sleep         374 non-null    int64
#  5   Physical Activity Level  374 non-null    int64
#  6   Stress Level             374 non-null    int64
#  7   BMI Category             374 non-null    object
#  8   Blood Pressure           374 non-null    object
#  9   Heart Rate               374 non-null    int64
#  10  Daily Steps              374 non-null    int64
#  11  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 38.0+ KB

# %%
df.describe()
# Out:
#               Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# count  374.000000      374.000000        374.000000               374.000000
# mean    42.184492        7.132086          7.312834                59.171123
# std      8.673133        0.795657          1.196956                20.830804
# min     27.000000        5.800000          4.000000                30.000000
# 25%     35.250000        6.400000          6.000000                45.000000
# 50%     43.000000        7.200000          7.000000                60.000000
# 75%     50.000000        7.800000          8.000000                75.000000
# max     59.000000        8.500000          9.000000                90.000000
#
#        Stress Level  Heart Rate   Daily Steps
# count    374.000000  374.000000    374.000000
# mean       5.385027   70.165775   6816.844920
# std        1.774526    4.135676   1617.915679
# min        3.000000   65.000000   3000.000000
# ...

# %%
df.describe(include='all')
# Out:
#        Gender         Age Occupation  Sleep Duration  Quality of Sleep  \
# count     374  374.000000        374      374.000000        374.000000
# unique      2         NaN         11             NaN               NaN
# top      Male         NaN      Nurse             NaN               NaN
# freq      189         NaN         73             NaN               NaN
# mean      NaN   42.184492        NaN        7.132086          7.312834
# std       NaN    8.673133        NaN        0.795657          1.196956
# min       NaN   27.000000        NaN        5.800000          4.000000
# 25%       NaN   35.250000        NaN        6.400000          6.000000
# 50%       NaN   43.000000        NaN        7.200000          7.000000
# 75%       NaN   50.000000        NaN        7.800000          8.000000
# max       NaN   59.000000        NaN        8.500000          9.000000
#
#         Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
df['BMI Category'].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64

# %%
df['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     4
# 128/85     3
# 132/87     3
# 117/76     2
# 130/86     2
# 126/83     2
# 119/77     2
# 135/88     2
# 128/84     2
# 131/86     2
# 139/91     2
# 115/78     2
# 129/84     2
# 142/92     2
# 118/75     2
# 118/76     1
# 122/80     1
# 121/79     1
# Name: count, dtype: int64

# %%
df['Blood Pressure'].value_counts()/len(df)*100
# Out:
# Blood Pressure
# 130/85    26.470588
# 140/95    17.379679
# 125/80    17.379679
# 120/80    12.032086
# 115/75     8.556150
# 135/90     7.219251
# 140/90     1.069519
# 125/82     1.069519
# 128/85     0.802139
# 132/87     0.802139
# 117/76     0.534759
# 130/86     0.534759
# 126/83     0.534759
# 119/77     0.534759
# 135/88     0.534759
# 128/84     0.534759
# 131/86     0.534759
# 139/91     0.534759
# 115/78     0.534759
# 129/84     0.534759
# 142/92     0.534759
# 118/75     0.534759
# 118/76     0.267380
# 122/80     0.267380
# 121/79     0.267380
# Name: count, dtype: float64

# %%
df['Sleep Duration'].mean()
# Out:
# np.float64(7.132085561497325)

# %%
df['Daily Steps'].mean()
# Out:
# np.float64(6816.844919786096)

# %%
df['Daily Steps'].median()
# Out:
# 7000.0

# %%
df['Blood Pressure'].max()
# Out:
# '142/92'

# %%
df['Sleep Duration'].min()
# Out:
# 5.8

# %%
df['Quality of Sleep'].value_counts()
# Out:
# Quality of Sleep
# 8    109
# 6    105
# 7     77
# 9     71
# 5      7
# 4      5
# Name: count, dtype: int64

# %%
df['Quality of Sleep'].mean()
# Out:
# np.float64(7.31283422459893)

# %%
df['Quality of Sleep'].median()
# Out:
# 7.0

# %%
df['Quality of Sleep'].quantile(0.50)
# Out:
# np.float64(7.0)

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# 6    46
# Name: count, dtype: int64

# %%
df['Stress Level'].mode()
# Out:
# 0    3
# Name: Stress Level, dtype: int64

# %%
df.Occupation.unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
df.Occupation.nunique()
# Out:
# 11

# %%
df.groupby('Sleep Disorder')['Stress Level'].mean()
# Out:
# Sleep Disorder
# Insomnia       5.870130
# Sleep Apnea    5.666667
# Name: Stress Level, dtype: float64

# %%
df.groupby('Occupation')['Quality of Sleep'].median()
# Out:
# Occupation
# Accountant              8.0
# Doctor                  7.0
# Engineer                9.0
# Lawyer                  8.0
# Manager                 7.0
# Nurse                   6.0
# Sales Representative    4.0
# Salesperson             6.0
# Scientist               5.0
# Software Engineer       7.0
# Teacher                 7.0
# Name: Quality of Sleep, dtype: float64

# %%
df.groupby(['Sleep Disorder', 'Gender'])['Sleep Duration'].mean()
# Out:
# Sleep Disorder  Gender
# Insomnia        Female    6.633333
#                 Male      6.551220
# Sleep Apnea     Female    7.035821
#                 Male      7.009091
# Name: Sleep Duration, dtype: float64

# %%
pd.crosstab(df['BMI Category'], df['Sleep Disorder'])
# Out:
# Sleep Disorder  Insomnia  Sleep Apnea
# BMI Category
# Normal                 7            5
# Normal Weight          2            2
# Obese                  4            6
# Overweight            64           65

# %%
pd.pivot_table(df, values='Daily Steps', index='Occupation', columns='Sleep Disorder')
# Out:
# Sleep Disorder           Insomnia  Sleep Apnea
# Occupation
# Accountant            6142.857143          NaN
# Doctor                4000.000000  5850.000000
# Engineer              6000.000000  8000.000000
# Lawyer                8000.000000  4866.666667
# Nurse                 6033.333333  8263.934426
# Sales Representative          NaN  3000.000000
# Salesperson           6000.000000  6000.000000
# Scientist                     NaN  5200.000000
# Software Engineer     3000.000000          NaN
# Teacher               5862.962963  5450.000000

# %%
df[(df['Stress Level'] > 7) & (df['Quality of Sleep'] < 5)&(df['Sleep Disorder']=='Sleep Apnea')]
# Out:
#            Gender  Age            Occupation  Sleep Duration  \
# Person ID
# 4            Male   28  Sales Representative             5.9
# 5            Male   28  Sales Representative             5.9
# 81         Female   34             Scientist             5.8
# 82         Female   34             Scientist             5.8
#
#            Quality of Sleep  Physical Activity Level  Stress Level  \
# Person ID
# 4                         4                       30             8
# 5                         4                       30             8
# 81                        4                       32             8
# 82                        4                       32             8
#
#           BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# Person ID
# 4                Obese         140/90          85         3000    Sleep Apnea
# 5                Obese         140/90          85         3000    Sleep Apnea
# ...

# %%
df[(df['Sleep Disorder']=='Insomnia')& (df['Stress Level']>=7)&(df['Quality of Sleep']<5)]
# Out:
#           Gender  Age         Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 6           Male   28  Software Engineer             5.9                 4
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 6                               30             8        Obese         140/90
#
#            Heart Rate  Daily Steps Sleep Disorder
# Person ID
# 6                  85         3000       Insomnia

# %%
df[(df['Stress Level'] > 7) & (df['Quality of Sleep'] < 5)]
# Out:
#            Gender  Age            Occupation  Sleep Duration  \
# Person ID
# 4            Male   28  Sales Representative             5.9
# 5            Male   28  Sales Representative             5.9
# 6            Male   28     Software Engineer             5.9
# 81         Female   34             Scientist             5.8
# 82         Female   34             Scientist             5.8
#
#            Quality of Sleep  Physical Activity Level  Stress Level  \
# Person ID
# 4                         4                       30             8
# 5                         4                       30             8
# 6                         4                       30             8
# 81                        4                       32             8
# 82                        4                       32             8
#
#           BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# Person ID
# 4                Obese         140/90          85         3000    Sleep Apnea
# ...

# %%
df.loc[50:130:5,['Age','Occupation','Quality of Sleep','Physical Activity Level','Stress Level','BMI Category','Sleep Disorder']]
# Out:
#            Age         Occupation  Quality of Sleep  Physical Activity Level  \
# Person ID
# 50          31             Doctor                 7                       75
# 55          32             Doctor                 6                       30
# 60          32             Doctor                 7                       75
# 65          32             Doctor                 6                       30
# 70          33          Scientist                 6                       50
# 75          33             Doctor                 6                       30
# 80          33             Doctor                 6                       30
# 85          35  Software Engineer                 8                       60
# 90          35           Engineer                 8                       60
# 95          36         Accountant                 8                       60
# 100         36            Teacher                 8                       60
# ...

# %%
df.iloc[10:15,[3,4,5,2,11]]
# Out:
#            Sleep Duration  Quality of Sleep  Physical Activity Level  \
# Person ID
# 11                    6.1                 6                       30
# 12                    7.8                 7                       75
# 13                    6.1                 6                       30
# 14                    6.0                 6                       30
# 15                    6.0                 6                       30
#
#           Occupation Sleep Disorder
# Person ID
# 11            Doctor            NaN
# 12            Doctor            NaN
# 13            Doctor            NaN
# 14            Doctor            NaN
# 15            Doctor            NaN

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Sleep Duration'], df['Stress Level'])
plt.title('Sleep Duration vs Stress Level')
plt.xlabel('Sleep Duration (hrs)')
plt.ylabel('Stress Level')
plt.grid(True)
plt.show()

# %%
df_sorted = df.sort_values('Age')
plt.figure(figsize=(8,5))
plt.plot(df_sorted['Age'], df_sorted['Heart Rate'], marker='o',color='purple')
plt.title('Heart Rate Trend by Age')
plt.xlabel('Age')
plt.ylabel('Heart Rate')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.pairplot(
    data=df,
    x_vars=['Quality of Sleep','Stress Level','Physical Activity Level'],
    kind='scatter')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='BMI Category', y='Sleep Duration', data=df, palette='Set2')
plt.title('Sleep Duration by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Sleep Duration (hours)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Sleep Duration'], color='skyblue',edgecolor='black')
plt.title('Distribution of Sleep Duration')
plt.xlabel('Hours of Sleep')
plt.ylabel('Number of People')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
sns.histplot(df['Sleep Duration'])
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Count'>

# %%
sns.countplot(x='Sleep Disorder', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
avg_quality = df.groupby('Occupation')['Quality of Sleep'].mean().sort_values()
plt.figure(figsize=(10,6))
avg_quality.plot(kind='bar', color='teal')
plt.title('Average Sleep Quality by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Quality of Sleep')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='Daily Steps', y='Occupation', data=df);

# %%
df['BMI Category'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # Conclusion
# We began by using essential data inspection functions like set_option(), head(0), tail(), info(), dtypes(), and describe() to understand the structure and summary statistics of the dataset. We then applied a range of aggregate functions—including mean(), median(), mode(), quantile(), and std()—to extract meaningful insights about pulse rate distribution.
#
# To further explore categorical and numerical patterns, we used:
# - value_counts(), unique(), and nunique() for frequency analysis
# - crosstab() and pivot_table() for multi-dimensional comparisons
# - groupby() and sort_values() for segment-wise analysis
# - loc() and iloc() for data selection
# - isnull().sum() and duplicated().sum() for data quality checks
# - drop() and dropna() for cleaning and refining the dataset
# -
# For visualization, we leveraged both Matplotlib and Seaborn to create:
# - Scatter plots to observe relationships
# - Histograms to examine distribution
# - Countplots and barplots to compare frequencies of data
# - Pie charts to represent categorical proportions
# These techniques helped us uncover trends such as how pulse rate varies with activity intensity and duration, and how dietary habits may correlate with cardiovascular response. Overall, this analysis provided a comprehensive understanding of the dataset and demonstrated the power of Python for data exploration and visualization.
